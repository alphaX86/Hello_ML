# %% [markdown]
# <a href="https://colab.research.google.com/github/alphaX86/Hello_ML/blob/master/Data_seperate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/11.2 Sri Venkateshwara College of Engineering and Technology_202015-11-19.csv")

# %%
data.head()
# Out:
#           Name  python  mysql  ...      Mobile                    Email Rising
# 0    A.Dharani    82.0   20.0  ...  8056669928  dharanianbu74@gmail.com      0
# 1  V.JEEVITHA     82.0   20.0  ...  9655705598  vjeevitha1998@gmail.com      0
# 2  HEMAVATHI.R   100.0  100.0  ...  7558186924   hemaravi0499@gmail.com      0
# 3  Mugunthan S   100.0   47.0  ...  7094532287  mugunthans718@gmail.com      0
# 4  Sathammai.S   100.0    8.0  ...  6374336788  vinayagar2324@gmail.com      0
#
# [5 rows x 9 columns]

# %%
pd.set_option('display.max_rows', 1000)
data_filter_1 = data[data["CodeKata Score"]>15000]
data_filter_1.head()
# Out:
#           Name  python  mysql  ...      Mobile                    Email Rising
# 0    A.Dharani    82.0   20.0  ...  8056669928  dharanianbu74@gmail.com      0
# 1  V.JEEVITHA     82.0   20.0  ...  9655705598  vjeevitha1998@gmail.com      0
# 2  HEMAVATHI.R   100.0  100.0  ...  7558186924   hemaravi0499@gmail.com      0
#
# [3 rows x 9 columns]

# %%
data_filter_2 = data[data["CodeKata Score"]>10000]
data_filter_2x = data_filter_2[data_filter_2["CodeKata Score"]<15000]
data_filter_2x
# Out:
#           Name  python  mysql  ...      Mobile                    Email Rising
# 3  Mugunthan S   100.0   47.0  ...  7094532287  mugunthans718@gmail.com      0
#
# [1 rows x 9 columns]

# %%
data_filter_3 = data[data["CodeKata Score"]>7000]
data_filter_3x = data_filter_3[data_filter_3["CodeKata Score"]<10000]
data_filter_3x
# Out:
#                    Name  python  ...                       Email  Rising
# 4           Sathammai.S   100.0  ...     vinayagar2324@gmail.com       0
# 5          NIVEESHWAR S   100.0  ...    sivanivesh2315@gmail.com       0
# 6         KALAIARASAN K    85.0  ...     kalai.ece.a.k@gmail.com     130
# 7  MOHAMED ZUBAIR AHMED    82.0  ...  mohamedzubair490@gmail.com       0
#
# [4 rows x 9 columns]

# %%
data_filter_4 = data[data["CodeKata Score"]<7000]
data_filter_4
# Out:
#                           Name  python  ...                            Email  Rising
# 8                   J.SUGANTHI    27.0  ...   suguudhayacharan2014@gmail.com       0
# 9                 thamizhpaana    29.0  ...              tamprider@gmail.com       0
# 10             Iyappan Samiraj    50.0  ...       shivaiyappan2210@gmail.com       0
# 11                Ponniyamma.R   100.0  ...          ponniravi2499@gmail.com       0
# 12                   SABAPATHI   100.0  ...         sharpsabapathi@gmail.com       0
# 13                    RAGHAVAN   100.0  ...            ragul291997@gmail.com       0
# 14             Melvin Dukles.R    56.0  ...           r.m.declas24@gmail.com       0
# 15                    Pavithra   100.0  ...         pavithraaflora@gmail.com       0
# 16                 PRIYANKA .S    85.0  ...        priyaprider7372@gmail.com       0
# 17                 v.vithyasri   100.0  ...            vithya61198@gmail.com       0
# ...

# %%
data_filter_1.to_csv("data1.csv")

# %%
data_filter_2x.to_csv("data2.csv")

# %%
data_filter_3x.to_csv("data3.csv")

# %%
data_filter_4.to_csv("data4.csv")
